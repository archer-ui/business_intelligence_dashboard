# %% [markdown]
# # 1. Milestone 1: Data Exploration and Visualization
#
# This milestone focuses on understanding the dataset through data exploration and visualization. The goal is to identify the structure of the dataset, assess data quality, and generate visual insights that will support further analysis in later milestones.

# %% [markdown]
# ## 1.1 Importing Libraries
# Import the necessary libraries required for data manipulation and visualization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.2 Loading the Data set
# The sample data set is loaded for analysis

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\USER\Desktop\visualization\sampledata.csv",
    encoding="latin1"
)

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800  01/03/2023  01/07/2023  Standard Class    DP-13000
# 1       2  US-2023-112326  01/04/2023  01/08/2023  Standard Class    PO-19195
# 2       3  US-2023-112326  01/04/2023  01/08/2023  Standard Class    PO-19195
# 3       4  US-2023-112326  01/04/2023  01/08/2023  Standard Class    PO-19195
# 4       5  US-2023-141817  01/05/2023  01/12/2023  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %% [markdown]
# ## 1.3 Previewing the data set
# The first five rows are displayed to ensure the data set loaded correctly.

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800  01/03/2023  01/07/2023  Standard Class    DP-13000
# 1       2  US-2023-112326  01/04/2023  01/08/2023  Standard Class    PO-19195
# 2       3  US-2023-112326  01/04/2023  01/08/2023  Standard Class    PO-19195
# 3       4  US-2023-112326  01/04/2023  01/08/2023  Standard Class    PO-19195
# 4       5  US-2023-141817  01/05/2023  01/12/2023  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %% [markdown]
# ## 1.4 Data set Information
#
# The data set information provides the number of rows and columns, data types, and non-null values for each variable.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  object
#  3   Ship Date       10194 non-null  object
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
#  16  Product Name    10194 non-null  object
# ...

# %% [markdown]
# ## 1.5 Statistical Summary
#
# Descriptive statistics are generated to summarize the numerical variables, including measures such as the mean, minimum, maximum, and standard deviation.

# %%
df.describe()
# Out:
#              Row ID         Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000  10194.000000
# mean    5097.500000    228.225854      3.791838      0.155385     28.673417
# std     2942.898656    619.906839      2.228317      0.206249    232.465115
# min        1.000000      0.444000      1.000000      0.000000  -6599.978000
# 25%     2549.250000     17.220000      2.000000      0.000000      1.760800
# 50%     5097.500000     53.910000      3.000000      0.200000      8.690000
# 75%     7645.750000    209.500000      5.000000      0.200000     29.297925
# max    10194.000000  22638.480000     14.000000      0.800000   8399.976000

# %% [markdown]
# ## 1.6 Checking Missing Value
# We checked whether the data set contains missing values that may affect the analysis.

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %% [markdown]
# ## 1.7 Checking for Duplicate Records
#
# Duplicate records are identified to ensure data accuracy.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Duplicate rows are removed to improve the quality of the data set.

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## 1.8.1 Total Sales by Category
#
# This visualization compares total sales across the different product categories.

# %%
sales_by_category = df.groupby("Category")["Sales"].sum()

sales_by_category.plot(kind="bar")
plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ### Observation
#
# Technology generated the highest total sales, followed by Furniture and Office Supplies. This suggests that Technology products contribute the largest share of revenue.

# %% [markdown]
# ## 1.8.2 Total Sales by Region
#
# This visualization compares total sales generated across the different regions to identify the highest and lowest performing markets.

# %%
sales_by_region = df.groupby("Region")["Sales"].sum()

sales_by_region.plot(kind="bar")
plt.title("Total Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Observation
#
# The chart compares total sales across the four regions. Regions with higher sales indicate stronger market performance and customer demand, while lower-performing regions may require additional marketing or sales strategies.

# %% [markdown]
# ## 1.8.3 Total Profit by Category
#
# This chart compares the total profit earned from each product category.

# %%
profit_by_category = df.groupby("Category")["Profit"].sum()

profit_by_category.plot(kind="bar", color="green")
plt.title("Total Profit by Category")
plt.xlabel("Category")
plt.ylabel("Total Profit")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Observation
#
# The visualization highlights which product categories contribute the most profit to the business. Comparing this with sales helps determine whether high sales also translate into high profitability.

# %% [markdown]
# ## 1.8.4 Correlation Heatmap

# %%
plt.figure(figsize=(8,6))

correlation = df[["Sales","Quantity","Discount","Profit"]].corr()

sns.heatmap(correlation,
            annot=True,
            cmap="coolwarm",
            linewidths=0.5)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# ### Observation
#
# The heat map reveals the strength and direction of relationships among numerical variables. Positive values indicate that two variables increase together, while negative values suggest an inverse relationship. This analysis helps identify factors that influence sales and profitability.

# %% [markdown]
# ## 1.8.5 Relationship Between Sales and Profit
#
# The scatter plot examines whether an increase in sales generally leads to an increase in profit.

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["Sales"], df["Profit"])

plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")

plt.show()

# %% [markdown]
# ### Observation
#
# The scatter plot illustrates the relationship between sales and profit. While many high-sales transactions also generate higher profits, some high-sales orders produce relatively low profit, suggesting the possible impact of discounts or high operational costs.

# %% [markdown]
# # 2. Milestone 2: Data Preparation and Feature Engineering
# This milestone focuses on cleaning, transforming, and engineering new features that improve data quality and provide additional insights for business decision-making.
# New variables are created to uncover patterns that are not directly visible in the raw data set.

# %% [markdown]
# ## 2.1 Data Grouping

# %% [markdown]
# ### 2.1.1 Grouping Sales by Category
#
# The data set is grouped according to product category to calculate the total sales generated by each category.

# %%
sales_by_category = df.groupby("Category")["Sales"].sum()

sales_by_category
# Out:
# Category
# Furniture          754747.7613
# Office Supplies    731893.3140
# Technology         839893.2790
# Name: Sales, dtype: float64

# %% [markdown]
# ### 2.1.2 Grouping Sales by Region
#
# The data set is grouped by region to calculate the total sales generated in each geographical region.

# %%
sales_by_region = df.groupby("Region")["Sales"].sum()

sales_by_region
# Out:
# Region
# Central    503170.6728
# East       691828.1680
# South      391721.9050
# West       739813.6085
# Name: Sales, dtype: float64

# %% [markdown]
# ### 2.1.3 Grouping Profit by Category
#
# The data set is grouped by product category to determine the total profit contributed by each category.

# %%
profit_by_category = df.groupby("Category")["Profit"].sum()

profit_by_category
# Out:
# Category
# Furniture           19729.9956
# Office Supplies    126023.4434
# Technology         146543.3756
# Name: Profit, dtype: float64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

df['Order Month'] = df['Order Date'].dt.to_period('M').astype(str)

# %%
monthly_sales = df.groupby("Order Month")["Sales"].sum()

monthly_sales
# Out:
# Order Month
# 2023-01     14518.0550
# 2023-02      4519.8920
# 2023-03     56933.9090
# 2023-04     28295.3450
# 2023-05     26319.7670
# 2023-06     34669.4796
# 2023-07     33946.3930
# 2023-08     28918.3385
# 2023-09     82670.4288
# 2023-10     32413.3390
# 2023-11     78826.9567
# 2023-12     72008.3085
# 2024-01     18461.9156
# 2024-02     11951.4110
# 2024-03     39978.6280
# 2024-04     34195.2085
# 2024-05     30246.9465
# 2024-06     24797.2920
# 2024-07     28765.3250
# 2024-08     37057.0042
# 2024-09     64627.0460
# 2024-10     31407.1335
# 2024-11     75972.5635
# 2024-12     75532.5572
# 2025-01     18830.3310
# 2025-02     22978.8150
# 2025-03     53031.0690
# 2025-04     38829.1590
# 2025-05     57042.8380
# 2025-06     40937.1480
# 2025-07     40300.4990
# 2025-08     31716.8143
# 2025-09     73521.6629
# 2025-10     59831.0010
# 2025-11     79411.9658
# 2025-12     97502.2770
# 2026-01     44259.2140
# 2026-02     20301.1334
# 2026-03     60728.4808
# ...

# %% [markdown]
# ## 2.2 Data Transformation

# %% [markdown]
# ### 2.2.1 Converting Order Date
#
# The **Order Date** column is converted from a text format into a date time format.This is essential for performing time-series analysis.

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

# %% [markdown]
# ## 2.3 Feature Engineering

# %% [markdown]
# ### 2.3.1 Order Month
#
# A new feature named **Order Month** is extracted from the Order Date column. This feature groups transactions by month, making it easier to identify seasonal trends and compare sales performance across different periods of the year.

# %%
df["Order Month"] = df["Order Date"].dt.month_name()

df[["Order Date", "Order Month"]].head()
# Out:
#   Order Date Order Month
# 0 2023-01-03     January
# 1 2023-01-04     January
# 2 2023-01-04     January
# 3 2023-01-04     January
# 4 2023-01-05     January

# %% [markdown]
# ### 2.3.2 Profit Margin (%)
#
# A new feature named Profit Margin (%) is calculated using the Sales and Profit columns. Profit margin measures profitability relative to sales, providing a more meaningful indicator of business performance and operational efficiency.

# %%
df["Profit Margin (%)"] = (df["Profit"] / df["Sales"]) * 100

df[["Sales", "Profit", "Profit Margin (%)"]].head()
# Out:
#      Sales   Profit  Profit Margin (%)
# 0   16.448   5.5512              33.75
# 1    3.540  -5.4870            -155.00
# 2   11.784   4.2717              36.25
# 3  272.736 -64.7748             -23.75
# 4   19.536   4.8840              25.00

# %% [markdown]
# ### 2.3.3 Sales Category
#
# The continuous Sales variable is converted into three categorical groups: low, medium, and high. Categorizing sales values simplifies analysis by grouping similar transactions together, making it easier to identify purchasing patterns and compare different levels of sales performance.

# %%
def sales_category(sales):
    if sales < 100:
        return "Low"
    elif sales < 500:
        return "Medium"
    else:
        return "High"

df["Sales Category"] = df["Sales"].apply(sales_category)

df[["Sales", "Sales Category"]].head()
df.to_csv("superstore_milestone2.csv", index=False)

# %% [markdown]
# ## 2.4 Reproducible Workflow
# The workflow followed in this milestone consists of:
#
# 1. Loading the cleaned data set.
# 2. Grouping data to summarize business performance.
# 3. Transforming date variables into date time format.
# 4. Creating new features through feature engineering.

# %% [markdown]
# # 3. Milestone 3: Visualization & Exploratory Analysis
# This milestone focuses on visually exploring the prepared data set.

# %% [markdown]
# ## 3.1 Monthly Sales Trend

# %%
monthly_sales = df.groupby("Order Month")["Sales"].sum()

month_order = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]

monthly_sales = monthly_sales.reindex(month_order)

plt.figure(figsize=(10,5))
monthly_sales.plot(kind="line", marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Order Month")
plt.ylabel("Total Sales")
plt.grid(True)

plt.show()

# %% [markdown]
# ### Observation
#
# The line graph shows how total sales change from one month to another. The fluctuations indicate that sales vary throughout the year, suggesting periods of higher and lower customer demand. These patterns can help the business identify seasonal trends and plan inventory and marketing strategies accordingly.

# %% [markdown]
# ## 3.2 Average Profit Margin by Category

# %%
profit_margin = df.groupby("Category")["Profit Margin (%)"].mean()

plt.figure(figsize=(8,5))
profit_margin.plot(kind="bar")

plt.title("Average Profit Margin by Category")
plt.xlabel("Category")
plt.ylabel("Average Profit Margin (%)")

plt.show()

# %% [markdown]
# ### Observation
#
# The bar chart compares the average profit margin across different product categories. It highlights which categories generate higher profitability relative to their sales and identifies those with lower profit margins.

# %% [markdown]
# ## 3.3 Distribution of Profit Margin

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Profit Margin (%)"], bins=25)

plt.title("Distribution of Profit Margin")
plt.xlabel("Profit Margin (%)")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ### Observation
#
# The histogram shows how Profit Margin (%) values are distributed across all transactions. Most observations are concentrated within a particular range, while fewer transactions fall into extremely high or low profit margins, indicating the presence of variation in profitability.

# %% [markdown]
# ## 3.4 Sales versus Profit Margin

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["Sales"], df["Profit Margin (%)"])

plt.title("Sales vs Profit Margin")
plt.xlabel("Sales")
plt.ylabel("Profit Margin (%)")

plt.show()

# %% [markdown]
# ### Observation
#
# The scatter plot illustrates the relationship between Sales and Profit Margin (%). The points indicate that transactions with higher sales do not always generate higher profit margins, suggesting that profitability may also be influenced by factors such as discounts or operating costs.

# %% [markdown]
# ## 3.5 Sales Category Distribution

# %%
sales_category_distribution = df["Sales Category"].value_counts()

plt.figure(figsize=(6,5))
sales_category_distribution.plot(kind="bar")

plt.title("Sales Category Distribution")
plt.xlabel("Sales Category")
plt.ylabel("Number of Orders")

plt.show()

# %% [markdown]
# ### Observation
#
# The bar chart displays the number of transactions within each sales category (Low, Medium, and High). This provides an overview of customer purchasing behavior and shows which sales category contains the largest proportion of transactions.

# %% [markdown]
# ## 3.6 Correlation Heatmap

# %%
plt.figure(figsize=(8,6))

correlation = df[
[
"Sales",
"Profit",
"Quantity",
"Discount",
"Profit Margin (%)"
]
].corr()

sns.heatmap(correlation,
            annot=True,
            cmap="coolwarm",
            linewidths=0.5)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# ### Observation
#
# The heat map illustrates the strength and direction of relationships among the numerical variables. Positive correlations indicate that two variables tend to increase together, while negative correlations suggest that an increase in one variable is associated with a decrease in another. Weak correlations indicate little or no linear relationship.

# %% [markdown]
# ## 3.7 Visualization Design Principles
#
# The visualizations in this project were designed by applying several visualization design principles such as clarity, simplicity, consistency, readability, appropriate colour use, accurate labelling, and emphasis.
#
# 1. Bar Chart (Sales by Category): The bar chart applies the principles of clarity and consistency whereby Clarity was achieved through a descriptive title, clearly labelled x-axis (Category) and y-axis (Sales), making it easy for users to understand what is being compared. Consistency was maintained by using the same colour for all bars, allowing viewers to focus on differences in bar height rather than colour variations. The chart size was large enough to ensure readability, while the axis labels and tick marks were clearly visible.
#
# 2. Line Chart (Monthly Sales Trend): The line chart applies the principles of accuracy and readability. Accuracy was achieved by arranging the months in chronological order on the x-axis, allowing the trend in sales to be represented correctly over time. Readability was enhanced through a clear title, labelled axes, an appropriately sized chart, and a single coloured line that is easy to follow. The legend clearly identifies the sales data, enabling viewers to interpret the trend without confusion.
#
# 3. Histogram (Sales Distribution): The histogram applies the principles of simplicity and clarity. Simplicity was achieved by grouping sales values into intervals (bins) without adding unnecessary visual elements, allowing viewers to concentrate on the distribution of the data. Clarity was ensured through labelled axes showing the sales ranges and frequency, an informative title, and an appropriate chart size. A single colour was used consistently to avoid distracting the audience.
#
# 4. Scatter Plot (Sales vs Profit / Discount vs Profit): The scatter plot applies the principles of clarity and appropriate colour use. Clarity was achieved by labelling both the x-axis and y-axis clearly, enabling viewers to identify the relationship between the two variables. Appropriate colour use helped distinguish the data points from the background, making clusters and patterns easier to observe. The chart size was sufficient to prevent overlapping points, and a legend was included to identify the plotted variables
#
# 5. Correlation Heatmap: The correlation heatmap applies the principles of clarity and appropriate colour use. Clarity was achieved through clearly labelled rows and columns showing the variables being compared, while the colour gradient helped users quickly identify strong and weak correlations. A colour legend was included to explain the meaning of the different colour intensities.
# The heatmap uses the relationship analysis strategy because it shows correlations between multiple variables at once. Unlike the scatter plot, which examines the relationship between two variables, the heatmap provides an overall view of relationships across the entire dataset.

# %% [markdown]
# ## 3.8 Comparison of Visualization Strategies
# Different visualization strategies were used such as comparison strategy, trend analysis strategy, distribution strategy and relationship strategy.
#
# The bar chart uses the comparison strategy, making it the most appropriate choice for comparing sales across different product categories. In contrast, the line chart uses the trend analysis strategy, which is more suitable for showing how sales change over time.
#
# The histogram applies the distribution strategy by illustrating how sales values are spread across different intervals, helping identify common ranges and patterns within the data. The scatter plot uses the relationship (correlation) strategy to determine whether there is an association between two numerical variables, such as sales and profit or discount and profit.
#
# Selecting different visualization strategies ensured that each chart effectively communicated the intended insight and supported accurate interpretation of the dataset.

# %% [markdown]
# ## 3.9 Design Justification
# The dashboard was designed following data visualization best practices to ensure that insights are communicated accurately, clearly, and efficiently. Each visualization type was selected based on the nature of the data and the analytical question it answers.
#
# 1. Line Graph (Monthly Sales Trend):
# A line graph was chosen because it is the most effective visualization for displaying data that changes over time. It enables users to easily identify trends, seasonal patterns, increases, decreases, and fluctuations in monthly sales. The continuous line emphasizes the progression of sales from one month to the next, making trend analysis straightforward.
#
# 2.  Bar Graphs (Category Comparisons):
# Bar charts were used to compare values across different categories, such as product categories and sales categories. Since each category is independent, bar graphs allow users to quickly compare the magnitude of values, identify the highest and lowest performers, and recognize differences between categories. Their simple structure also makes them easy to interpret for both technical and non-technical users.
#
# 3. Histogram (Profit Margin Distribution):
# A histogram was selected because it is specifically designed to display the distribution of continuous numerical data. It groups profit margin values into intervals, making it easier to identify the spread of the data, concentration of observations, skewness, and any unusual values or outliers. This helps determine whether profit margins are evenly distributed or clustered within specific ranges.
#
# 4. Scatter Plot (Sales vs Profit Margin):
# The scatter plot was chosen to examine the relationship between Sales and Profit Margin (%). By plotting individual observations, it becomes easier to identify positive or negative correlations, clusters, trends, and potential outliers that may not be visible in summary statistics alone. This visualization helps determine whether higher sales consistently lead to higher profitability.
#
# 5. Correlation Heat Map:
# The heat map was selected because it provides a compact visual summary of correlations among multiple numerical variables simultaneously. Instead of comparing variables individually, users can quickly identify strong positive, strong negative, or weak relationships through differences in color intensity, making it an efficient tool for exploratory data analysis.
# Colour Selection Justification
#
# The dashboard uses a consistent and professional colour scheme to improve readability and user experience.
#
# 1. Blue was used for most visualizations because it represents trust, stability, and professionalism while remaining comfortable to view for extended periods.
#
# 2. Green was used where appropriate to represent positive performance, growth, and profitability, as it is naturally associated with financial success.
#
# 3. Orange or warm colours were used selectively to draw attention to important comparisons or high-value categories without overwhelming the viewer.
#
# 4. Gradient colours in the heat map were chosen because they clearly distinguish between weak and strong correlations. Darker shades represent stronger relationships, while lighter shades indicate weaker relationships, allowing users to interpret the matrix at a glance.
#
# 5. A white background with high-contrast text and chart elements was maintained to enhance readability, reduce visual clutter, and ensure that the data remains the primary focus rather than decorative elements.
#
# Overall, the dashboard emphasizes clarity, consistency, simplicity, and effective communication of insights. The chosen chart types and colour palette work together to help users identify trends, compare categories, understand distributions, detect relationships, and make informed business decisions quickly.

# %% [markdown]
# ## 3.10 Insight Analysis Report
# Monthly Sales Trend:
# The monthly sales trend indicates noticeable fluctuations in sales performance throughout the year, suggesting that customer demand is influenced by seasonal factors, promotional campaigns, or market conditions. Months with higher sales represent periods of increased customer activity, while lower sales periods may indicate reduced demand or operational challenges. Understanding these trends enables management to forecast future sales more accurately, optimize inventory levels, allocate staff efficiently, and schedule marketing campaigns during slower periods to improve revenue consistency.
#
# Average Profit Margin by Product Category:
# The comparison of average profit margins across product categories reveals that some categories generate significantly higher returns than others. This suggests that not all products contribute equally to the organization's profitability. High-margin categories should be prioritized through targeted marketing, increased inventory, and strategic investment, while lower-margin categories should be reviewed to identify opportunities for cost reduction, price adjustments, or product improvement. This analysis supports better product portfolio management and profit optimization.
#
# Distribution of Profit Margin (%):
# The histogram demonstrates that the majority of transactions are concentrated within a specific profit margin range, indicating relatively consistent profitability across most sales. A small number of observations fall outside this range, representing unusually high or low profit margins. These outliers may result from special promotions, pricing strategies, exceptional operational costs, or unique customer transactions. Investigating these exceptional cases can help management identify best practices to replicate and inefficiencies that require corrective action.
#
# Sales versus Profit Margin Relationship:
# The scatter plot shows that higher sales values do not consistently correspond to higher profit margins, indicating that sales volume alone is not a reliable measure of business success. Some high-sales transactions generate relatively low profits due to factors such as heavy discounting, high production costs, or operational expenses. Conversely, some lower-sales transactions achieve stronger profit margins. This finding highlights the importance of balancing revenue growth with profitability by implementing effective pricing strategies, controlling operational costs, and focusing on high-value customer segments.
#
# Sales Category Distribution:
# The distribution of sales across Low, Medium, and High-value transaction categories provides insight into customer purchasing behaviour. If most transactions fall within the lower-value categories, the business has an opportunity to increase average transaction value through cross-selling, upselling, promotional bundles, or customer loyalty programs. If high-value transactions dominate, management should focus on maintaining customer satisfaction and retention while continuing to attract premium customers. This analysis supports strategic marketing and sales planning.
#
# Correlation Heat Map:
# The correlation heat map provides a comprehensive overview of the relationships among key numerical variables within the dataset. Strong positive correlations indicate variables that tend to increase together, while weak or negative correlations suggest limited or inverse relationships. Understanding these relationships helps management identify the factors that most strongly influence business performance, avoid relying on a single performance metric, and make data-driven decisions based on multiple indicators. The heat map also provides valuable guidance for predictive modelling and future business intelligence analyses.
# Overall Conclusion
#
# The dashboard demonstrates that effective business decisions should be based on a combination of sales trends, profitability analysis, customer purchasing behaviour, and relationships between key performance indicators. The visualizations collectively show that maximizing sales alone is insufficient; sustainable business growth depends on maintaining healthy profit margins, identifying high-performing product categories, understanding customer behaviour, and using data-driven insights to improve strategic planning. The dashboard therefore serves as an effective decision-support tool by transforming raw business data into meaningful and actionable insights

# %% [markdown]
# The purpose of this milestone is to statistically validate the observations made in milestone 3 using inferential statistics and analytical models rather than relying on visual patterns. We started by importing additional libraries required for statistical analysis

# %% [markdown]
# ## 4.1 Importing Statistical Libraries
#
# The `scipy.stats` module is imported to carry out the independent t-test and the accompanying Levene's test for equality of variances.

# %%
from scipy import stats

# %% [markdown]
# ## 4.2 Formulating the Hypotheses
#
# Milestone 3 visually suggested that discounting is associated with lower profit, and that profitability differs across product categories. These observations are now tested statistically using the **independent t-test**, which compares the means of two independent groups.
#
# **Test 1 – Discount and Profit**
# - H0: There is no difference in mean Profit between discounted and non-discounted orders (μ1 = μ2)
# - H1: There is a significant difference in mean Profit between discounted and non-discounted orders (μ1 ≠ μ2)
#
# **Test 2 – Profit Margin: Technology vs Office Supplies**
# - H0: There is no difference in mean Profit Margin (%) between the Technology and Office Supplies categories (μ1 = μ2)
# - H1: There is a significant difference in mean Profit Margin (%) between the Technology and Office Supplies categories (μ1 ≠ μ2)
#
# **Test 3 – Sales: Central vs East Region**
# - H0: There is no difference in mean Sales between the Central and East regions (μ1 = μ2)
# - H1: There is a significant difference in mean Sales between the Central and East regions (μ1 ≠ μ2)
#
# For all tests, a significance level of **α = 0.05** is used.

# %% [markdown]
# ## 4.3 Test 1: Effect of Discount on Profit
#
# Orders are split into two independent groups — discounted (`Discount` > 0) and non-discounted (`Discount` = 0) — and their mean Profit is compared.

# %%
discounted = df[df["Discount"] > 0]["Profit"]
no_discount = df[df["Discount"] == 0]["Profit"]

print("Discounted orders   -> n:", len(discounted), " mean profit:", round(discounted.mean(), 2))
print("Non-discounted orders -> n:", len(no_discount), " mean profit:", round(no_discount.mean(), 2))

levene_stat, levene_p = stats.levene(discounted, no_discount)
print(f"\nLevene's test statistic: {levene_stat:.4f}, p-value: {levene_p:.4f}")

equal_var = levene_p > 0.05

t_stat, p_value = stats.ttest_ind(discounted, no_discount, equal_var=equal_var)

print(f"\nT-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("\nResult: Reject H0 - there is a statistically significant difference in mean Profit between discounted and non-discounted orders.")
else:
    print("\nResult: Fail to reject H0 - no statistically significant difference in mean Profit was found.")
# Out:
# Discounted orders   -> n: 5269  mean profit: -6.53
# Non-discounted orders -> n: 4925  mean profit: 66.34
#
# Levene's test statistic: 2.2059, p-value: 0.1375
#
# T-statistic: -16.0129
# P-value: 0.0000
#
# Result: Reject H0 - there is a statistically significant difference in mean Profit between discounted and non-discounted orders.

# %% [markdown]
# ### Observation
#
# The Levene's test result indicates whether the equal-variance assumption holds, which determines whether the standard Student's t-test or Welch's t-test is used. The resulting p-value is compared against α = 0.05 to determine whether discounting has a statistically significant effect on Profit, confirming (or challenging) the pattern seen in the Milestone 3 scatter plot of Discount vs Profit.

# %% [markdown]
# ## 4.4 Test 2: Profit Margin — Technology vs Office Supplies
#
# The two highest-volume product categories are compared to statistically validate the differences in average Profit Margin (%) observed in Milestone 3.

# %%
tech_margin = df[df["Category"] == "Technology"]["Profit Margin (%)"]
office_margin = df[df["Category"] == "Office Supplies"]["Profit Margin (%)"]

print("Technology       -> n:", len(tech_margin), " mean margin:", round(tech_margin.mean(), 2))
print("Office Supplies  -> n:", len(office_margin), " mean margin:", round(office_margin.mean(), 2))

levene_stat2, levene_p2 = stats.levene(tech_margin, office_margin)
print(f"\nLevene's test statistic: {levene_stat2:.4f}, p-value: {levene_p2:.4f}")

equal_var2 = levene_p2 > 0.05

t_stat2, p_value2 = stats.ttest_ind(tech_margin, office_margin, equal_var=equal_var2)

print(f"\nT-statistic: {t_stat2:.4f}")
print(f"P-value: {p_value2:.4f}")

if p_value2 < alpha:
    print("\nResult: Reject H0 - Profit Margin (%) differs significantly between Technology and Office Supplies.")
else:
    print("\nResult: Fail to reject H0 - no statistically significant difference in Profit Margin (%) was found.")
# Out:
# Technology       -> n: 1865  mean margin: 15.77
# Office Supplies  -> n: 6128  mean margin: 14.0
#
# Levene's test statistic: 105.6687, p-value: 0.0000
#
# T-statistic: 2.0157
# P-value: 0.0439
#
# Result: Reject H0 - Profit Margin (%) differs significantly between Technology and Office Supplies.

# %% [markdown]
# ### Observation
#
# This test statistically confirms whether the difference in average Profit Margin (%) between Technology and Office Supplies seen in the Milestone 3 bar chart (Section 3.2) is a genuine effect or could plausibly be due to random variation in the sample.

# %% [markdown]
# ## 4.5 Test 3: Sales — Central vs East Region
#
# Sales are compared between the Central and East regions to determine whether the regional differences observed in Milestone 1 (Section 1.8.2) are statistically significant.

# %%
central_sales = df[df["Region"] == "Central"]["Sales"]
east_sales = df[df["Region"] == "East"]["Sales"]

print("Central -> n:", len(central_sales), " mean sales:", round(central_sales.mean(), 2))
print("East    -> n:", len(east_sales), " mean sales:", round(east_sales.mean(), 2))

levene_stat3, levene_p3 = stats.levene(central_sales, east_sales)
print(f"\nLevene's test statistic: {levene_stat3:.4f}, p-value: {levene_p3:.4f}")

equal_var3 = levene_p3 > 0.05

t_stat3, p_value3 = stats.ttest_ind(central_sales, east_sales, equal_var=equal_var3)

print(f"\nT-statistic: {t_stat3:.4f}")
print(f"P-value: {p_value3:.4f}")

if p_value3 < alpha:
    print("\nResult: Reject H0 - mean Sales differs significantly between the Central and East regions.")
else:
    print("\nResult: Fail to reject H0 - no statistically significant difference in mean Sales was found.")
# Out:
# Central -> n: 2335  mean sales: 215.49
# East    -> n: 2986  mean sales: 231.69
#
# Levene's test statistic: 0.5543, p-value: 0.4566
#
# T-statistic: -0.9483
# P-value: 0.3430
#
# Result: Fail to reject H0 - no statistically significant difference in mean Sales was found.

# %% [markdown]
# ### Observation
#
# The result indicates whether the apparent gap in total sales between the Central and East regions reflects a genuine difference in average order value, or whether it is more likely driven by differences in the number of orders placed rather than the size of individual transactions.

# %% [markdown]
# ## 4.7 Summary of Hypothesis Testing
#
# | Test | Comparison | Metric | Significant? (α = 0.05) |
# |---|---|---|---|
# | 1 | Discounted vs Non-discounted orders | Profit | See p-value in Section 4.3 |
# | 2 | Technology vs Office Supplies | Profit Margin (%) | See p-value in Section 4.4 |
# | 3 | Central vs East region | Sales | See p-value in Section 4.5 |
#
# The independent t-tests move the analysis from visual, descriptive observations (Milestone 3) to inferential conclusions: they quantify how confident we can be that the differences seen in the charts reflect real underlying differences in the population of orders, rather than random sampling variation. Where a test is significant, the corresponding Cohen's d indicates whether the effect is large enough to be practically meaningful for business decision-making (e.g. discount policy, category investment, or regional strategy).

# %% [markdown]
# ## 4.8 Chi-Square Test of Independence
#
# The t-tests above compare means of a numeric variable across two groups. To test whether two **categorical** variables are associated (rather than independent), a chi-square test of independence is used. Here we test whether **Ship Mode** is associated with **Segment**.
#
# - H0: Ship Mode and Segment are independent (no association)
# - H1: Ship Mode and Segment are associated

# %%
contingency_table = pd.crosstab(df["Ship Mode"], df["Segment"])
contingency_table
# Out:
# Segment         Consumer  Corporate  Home Office
# Ship Mode
# First Class          777        487          284
# Same Day             317        118          112
# Second Class        1042        611          326
# Standard Class      3145       1874         1101

# %%
chi2_stat, chi2_p, dof, expected = stats.chi2_contingency(contingency_table)

print(f"Chi-square statistic: {chi2_stat:.4f}")
print(f"Degrees of freedom:   {dof}")
print(f"P-value:              {chi2_p:.4f}")

if chi2_p < alpha:
    print("\nResult: Reject H0 - Ship Mode and Segment are significantly associated.")
else:
    print("\nResult: Fail to reject H0 - no significant association found between Ship Mode and Segment.")
# Out:
# Chi-square statistic: 24.5820
# Degrees of freedom:   6
# P-value:              0.0004
#
# Result: Reject H0 - Ship Mode and Segment are significantly associated.

# %% [markdown]
# ### Observation
#
# The chi-square test evaluates whether the distribution of shipping preferences differs meaningfully across customer segments. A significant result would suggest that segment-specific shipping strategies (e.g. promoting faster shipping to a particular segment) could be worthwhile; a non-significant result suggests shipping preference is unrelated to segment.

# %% [markdown]
# ## 4.9 Correlation Analysis
#
# The Milestone 3 heatmap (Section 3.6) showed the *strength* of linear relationships between numeric variables. Here, Pearson correlation coefficients are calculated together with their p-values to test whether each correlation is **statistically significant**, not just descriptively present.
#
# - H0: There is no linear correlation between the two variables (ρ = 0)
# - H1: There is a linear correlation between the two variables (ρ ≠ 0)

# %%
pairs = [
    ("Sales", "Profit"),
    ("Discount", "Profit"),
    ("Quantity", "Profit"),
    ("Sales", "Profit Margin (%)"),
]

print(f"{'Variable 1':<20}{'Variable 2':<20}{'r':>8}{'p-value':>12}{'Significant?':>15}")
for var1, var2 in pairs:
    r, p = stats.pearsonr(df[var1], df[var2])
    sig = "Yes" if p < alpha else "No"
    print(f"{var1:<20}{var2:<20}{r:>8.3f}{p:>12.4f}{sig:>15}")
# Out:
# Variable 1          Variable 2                 r     p-value   Significant?
# Sales               Profit                 0.481      0.0000            Yes
# Discount            Profit                -0.219      0.0000            Yes
# Quantity            Profit                 0.066      0.0000            Yes
# Sales               Profit Margin (%)      0.003      0.7846             No

# %% [markdown]
# ### Observation
#
# Statistically significant correlations (p < 0.05) confirm that the relationships observed visually in Milestone 3 are unlikely to be due to chance. The strength (r) indicates how strong each relationship is: values near 0 indicate a weak linear relationship, while values closer to ±1 indicate a strong one. Note that a statistically significant correlation does not by itself imply causation — for example, a significant negative correlation between Discount and Profit indicates association, not proof that discounts directly cause profit loss.

# %% [markdown]
# ## 4.10 Regression Analysis
#
# A simple linear regression is used to model **Profit as a function of Discount**, quantifying the relationship and testing whether Discount is a statistically significant predictor of Profit.

# %%
x = df["Discount"]
y = df["Profit"]

slope, intercept, r_value, p_value_reg, std_err = stats.linregress(x, y)

print(f"Regression equation: Profit = {intercept:.3f} + ({slope:.3f}) * Discount")
print(f"R-squared:           {r_value**2:.4f}")
print(f"P-value (slope):     {p_value_reg:.6f}")
print(f"Standard error:      {std_err:.4f}")

if p_value_reg < alpha:
    print("\nResult: Discount is a statistically significant predictor of Profit.")
else:
    print("\nResult: Discount is not a statistically significant predictor of Profit.")
# Out:
# Regression equation: Profit = 67.007 + (-246.704) * Discount
# R-squared:           0.0479
# P-value (slope):     0.000000
# Standard error:      10.8937
#
# Result: Discount is a statistically significant predictor of Profit.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x, y, alpha=0.4, label="Observed data")
x_line = np.linspace(x.min(), x.max(), 100)
y_line = intercept + slope * x_line
plt.plot(x_line, y_line, color="red", label="Fitted regression line")
plt.title("Linear Regression: Discount vs Profit")
plt.xlabel("Discount")
plt.ylabel("Profit")
plt.legend()
plt.show()

# %% [markdown]
# ### Observation
#
# The R-squared value indicates the proportion of variability in Profit explained by Discount alone; a low R-squared suggests other factors (Category, Quantity, Region, etc.) also drive profitability. The p-value for the slope tests whether the relationship is statistically distinguishable from zero, providing a formal, model-based counterpart to the Milestone 1 scatter plot of Discount vs Profit.

# %% [markdown]
# ## 4.11 Time Series / Trend Analysis
#
# The Milestone 3 line chart (Section 3.1) showed monthly sales fluctuations. Here, a linear trend is fitted over time to test whether sales show a statistically significant upward or downward trend across the year.

# %%
month_order = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]

monthly_sales_trend = df.groupby("Order Month")["Sales"].sum().reindex(month_order)

time_index = np.arange(len(monthly_sales_trend))
sales_values = monthly_sales_trend.values

slope_t, intercept_t, r_value_t, p_value_t, std_err_t = stats.linregress(time_index, sales_values)

print(f"Trend equation: Sales = {intercept_t:.2f} + ({slope_t:.2f}) * Month_Index")
print(f"R-squared:      {r_value_t**2:.4f}")
print(f"P-value:        {p_value_t:.4f}")

if p_value_t < alpha:
    direction = "increasing" if slope_t > 0 else "decreasing"
    print(f"\nResult: Statistically significant {direction} trend in monthly sales.")
else:
    print("\nResult: No statistically significant trend in monthly sales - fluctuations appear to be random/seasonal rather than a consistent trend.")
# Out:
# Trend equation: Sales = 77614.71 + (21138.76) * Month_Index
# R-squared:      0.6793
# P-value:        0.0010
#
# Result: Statistically significant increasing trend in monthly sales.

# %%
plt.figure(figsize=(10, 5))
plt.plot(month_order, sales_values, marker="o", label="Monthly Sales")
plt.plot(month_order, intercept_t + slope_t * time_index, color="red", linestyle="--", label="Trend line")
plt.title("Monthly Sales Trend with Fitted Trend Line")
plt.xlabel("Order Month")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Observation
#
# Fitting a trend line statistically validates whether the fluctuations seen in Milestone 3 reflect a genuine directional trend over the year, or whether sales are essentially flat with random/seasonal variation around a stable average. This distinction matters for forecasting and planning purposes.

# %% [markdown]
# ## 4.12 Interpretation of Uncertainty and Variability
#
# Point estimates (means, totals) do not convey how much uncertainty surrounds them. 95% confidence intervals are calculated for key metrics to express the range within which the true population mean is likely to fall.

# %%
def confidence_interval(data, confidence=0.95):
    data = np.array(data)
    n = len(data)
    mean = data.mean()
    sem = stats.sem(data)  # standard error of the mean
    margin = sem * stats.t.ppf((1 + confidence) / 2, n - 1)
    return mean, mean - margin, mean + margin

metrics = {
    "Overall Profit": df["Profit"],
    "Overall Sales": df["Sales"],
    "Discounted Orders - Profit": discounted,
    "Non-discounted Orders - Profit": no_discount,
}

print(f"{'Metric':<32}{'Mean':>12}{'95% CI Lower':>16}{'95% CI Upper':>16}")
for name, series in metrics.items():
    mean, lower, upper = confidence_interval(series)
    print(f"{name:<32}{mean:>12.2f}{lower:>16.2f}{upper:>16.2f}")
# Out:
# Metric                                  Mean    95% CI Lower    95% CI Upper
# Overall Profit                         28.67           24.16           33.19
# Overall Sales                         228.23          216.19          240.26
# Discounted Orders - Profit             -6.53          -12.03           -1.04
# Non-discounted Orders - Profit         66.34           59.23           73.45

# %% [markdown]
# ### Observation
#
# The confidence intervals show the precision of each estimate. Narrow intervals indicate more reliable estimates (typically from larger or less variable groups), while wide intervals signal greater uncertainty. Where the confidence intervals for two groups (e.g. discounted vs non-discounted Profit) do not overlap, this reinforces the conclusion of a significant difference found in the t-test; overlapping intervals suggest more caution is warranted even if a test returned a low p-value.

# %% [markdown]
# ## 4.13 Statistical Evaluation Report
#
# This report summarizes the statistical validation of the observations made in Milestone 3, using the inferential tests carried out in this milestone.
#
# **1. Discounting and Profit**
# The independent t-test (Section 4.3) and regression analysis (Section 4.10) both examine the relationship between Discount and Profit. Together they indicate whether higher discounts are statistically associated with a genuine reduction in profit, and how much of the variation in Profit can be explained by Discount alone (via R-squared).
#
# **2. Category-Level Profitability**
# The t-test comparing Technology and Office Supplies (Section 4.4) statistically confirms whether the profit margin gap seen in the Milestone 3 bar chart reflects a real difference in profitability between categories, rather than sampling noise.
#
# **3. Regional Sales Performance**
# The t-test comparing Central and East region sales (Section 4.5) tests whether the visual difference in regional performance from Milestone 1 is statistically meaningful at the order level.
#
# **4. Shipping and Segment Association**
# The chi-square test (Section 4.8) evaluates whether shipping mode preference depends on customer segment, extending the analysis beyond numeric comparisons into categorical association.
#
# **5. Correlation Structure**
# The Pearson correlation tests (Section 4.9) confirm which pairwise relationships among Sales, Profit, Discount, and Quantity are statistically significant, adding formal support to the Milestone 3 correlation heatmap.
#
# **6. Sales Trend Over Time**
# The time-series trend analysis (Section 4.11) tests whether monthly sales show a statistically significant directional trend across the year, rather than only describing month-to-month fluctuations visually.
#
# **7. Uncertainty**
# The 95% confidence intervals (Section 4.12) quantify the precision of the key summary statistics used throughout this analysis, ensuring conclusions are interpreted with appropriate caution rather than treating point estimates as exact figures.
#
# *(Once each code cell above is run against the actual data set, the specific p-values, R-squared values, and confidence intervals obtained should be inserted into the corresponding paragraph above to complete this report with the actual results.)*

# %% [markdown]
# ## 4.14 Insight Validation and Explanation
#
# This section links each statistically tested result back to a concrete business implication:
#
# - **If Discount is confirmed to significantly reduce Profit:** discounting policy should be reviewed, e.g. capping discount levels for high-risk product categories or setting minimum margin thresholds before a discount is approved.
# - **If Profit Margin differs significantly between Technology and Office Supplies:** resource allocation, marketing spend, and inventory investment can be weighted more heavily toward the higher-margin category, provided sales volume is also considered.
# - **If Sales differ significantly between the Central and East regions:** region-specific sales strategies or targeted marketing campaigns may be warranted to close the performance gap, and the confidence intervals from Section 4.12 indicate how much variability to expect around the current averages.
# - **If Ship Mode and Segment are found to be associated:** shipping options and messaging can be tailored to the preferences of each customer segment.
# - **If the sales trend analysis shows no significant directional trend:** management should treat monthly fluctuations as expected seasonal or random variation rather than planning around a false sense of sustained growth or decline.
#
# Overall, this milestone moves the project from *descriptive* insight ("what the data shows") to *inferential* insight ("how confident we can be that what the data shows reflects a real, generalizable pattern"), which is the foundation needed before building predictive or prescriptive analytical models in later work.
