# %%
import pandas as pd
# Import the pandas library for data analysis.

# %%
df = pd.read_csv("sample_data.csv", encoding='latin-1')
# A DataFrame is a table-like structure that makes it easy to analyze data.
# This allows us to perform statistical analysis on the dataset.

# %%
df.head()
# Display the first five rows of the dataset
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800   1/3/2023   1/7/2023  Standard Class    DP-13000
# 1       2  US-2023-112326   1/4/2023   1/8/2023  Standard Class    PO-19195
# 2       3  US-2023-112326   1/4/2023   1/8/2023  Standard Class    PO-19195
# 3       4  US-2023-112326   1/4/2023   1/8/2023  Standard Class    PO-19195
# 4       5  US-2023-141817   1/5/2023  1/12/2023  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %%
# Display the number of rows and columns in the dataset
df.shape
# Out:
# (4589, 21)

# %%
# Generate descriptive statistics for all numerical columns
df.describe()
# Out:
#             Row ID         Sales     Quantity     Discount       Profit
# count  4589.000000   4588.000000  4588.000000  4588.000000  4588.000000
# mean   2295.000000    234.396218     3.796861     0.154385    27.411884
# std    1324.874522    624.736886     2.233613     0.206002   193.845897
# min       1.000000      0.852000     1.000000     0.000000 -3701.892800
# 25%    1148.000000     17.407500     2.000000     0.000000     1.678200
# 50%    2295.000000     56.300000     3.000000     0.150000     8.879200
# 75%    3442.000000    216.660000     5.000000     0.200000    31.276000
# max    4589.000000  22638.480000    14.000000     0.800000  4630.475500

# %%
# Calculate the mean of all numerical columns
df.mean(numeric_only=True)
# Out:
# Row ID      2295.000000
# Sales        234.396218
# Quantity       3.796861
# Discount       0.154385
# Profit        27.411884
# dtype: float64

# %%
# Calculate the median of all numerical columns
df.median(numeric_only=True)
# Out:
# Row ID      2295.0000
# Sales         56.3000
# Quantity       3.0000
# Discount       0.1500
# Profit         8.8792
# dtype: float64

# %%
# Calculate the standard deviation of all numerical columns
df.std(numeric_only=True)
# Out:
# Row ID      1324.874522
# Sales        624.736886
# Quantity       2.233613
# Discount       0.206002
# Profit       193.845897
# dtype: float64

# %%
# Calculate the variance of all numerical columns
df.var(numeric_only=True)
# Out:
# Row ID      1.755292e+06
# Sales       3.902962e+05
# Quantity    4.989029e+00
# Discount    4.243671e-02
# Profit      3.757623e+04
# dtype: float64

# %%
# Find the mode of all numerical columns
df.mode(numeric_only=True)
# Out:
#       Row ID  Sales  Quantity  Discount  Profit
# 0          1  12.96       3.0       0.0     0.0
# 1          2    NaN       NaN       NaN     NaN
# 2          3    NaN       NaN       NaN     NaN
# 3          4    NaN       NaN       NaN     NaN
# 4          5    NaN       NaN       NaN     NaN
# ...      ...    ...       ...       ...     ...
# 4584    4585    NaN       NaN       NaN     NaN
# 4585    4586    NaN       NaN       NaN     NaN
# 4586    4587    NaN       NaN       NaN     NaN
# 4587    4588    NaN       NaN       NaN     NaN
# 4588    4589    NaN       NaN       NaN     NaN
#
# [4589 rows x 5 columns]

# %%
# Calculate the correlation between numerical variables
df.corr(numeric_only=True)
# Out:
#             Row ID     Sales  Quantity  Discount    Profit
# Row ID    1.000000 -0.002058  0.003102 -0.004868  0.012997
# Sales    -0.002058  1.000000  0.207830 -0.018482  0.323763
# Quantity  0.003102  0.207830  1.000000  0.004263  0.059615
# Discount -0.004868 -0.018482  0.004263  1.000000 -0.261937
# Profit    0.012997  0.323763  0.059615 -0.261937  1.000000
